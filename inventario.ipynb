# %% [markdown]
# # Actividad práctica: Gestión de inventario
# ## **Objetivo:** Modelar datos usando estructuras de listas y diccionarios.
# ## **Recuerda:** las celdas se ejecutan usando la combinación `Ctrl+Enter`.

# %% [markdown]
# ### 1. Carga el siguiente catálogo

# %%
# Cargando el catalogo
catalogo_productos = {
101: {
"nombre": "Laptop Ultrabook",
"precio": 1200.00,
"cantidad_en_stock": 15,
"categoria": "Electrónica",
"proveedor": "TechGlobal"
},
102: {
"nombre": "Monitor Curvo 27",
"precio": 350.50,
"cantidad_en_stock": 30,
"categoria": "Electrónica",
"proveedor": "ViewTech"
},
103: {
"nombre": "Teclado Mecánico RGB",
"precio": 85.99,
"cantidad_en_stock": 50,
"categoria": "Electrónica",
"proveedor": "GamerGear"
},
201: {
"nombre": "Camiseta de Algodón",
"precio": 25.00,
"cantidad_en_stock": 100,
"categoria": "Ropa",
"proveedor": "FashionWear"
},
301: {
"nombre": "Café Colombiano 500g","precio": 12.75,
"cantidad_en_stock": 80,
"categoria": "Alimentos",
"proveedor": "CafeExcellence"
}
}

# %% [markdown]
# ## 2. Agregar nuevo producto
# - Agrega un nuevo producto con ID 401 y los siguientes detalles:
#     - nombre: "Ratón Inalámbrico Ergonómico"
#     - precio: 45.00
#     -  cantidad_en_stock: 40
#     -  categoria: "Electrónica"
#      - proveedor: "ErgoDevices"
# - Después de agregarlo, imprime el catálogo completo para verificar.

# %% [markdown]
# ### 3. Actualizar Información de un Producto¶

# %% [markdown]
# - El Monitor Curvo 27 (ID 102) ha bajado de precio. Actualiza su precio a 320.00.
#
# - La Camiseta de Algodón (ID 201) ha recibido una nueva entrega. Aumenta su cantidad_en_stock
# en 20 unidades
# - Imprime solo la información actualizada del Monitor Curvo 27 y la Camiseta de Algodón
# para verificar los cambios.

# %% [markdown]
# ### 4. Consultar información específica
# - Imprime el nombre y la categoría del producto con ID 103.
# - Verifica si existe un producto con ID 999. Si no existe, imprime un mensaje que lo indique.

# %% [markdown]
# ### 5. Listar Productos por Categoría
# - Crea un bucle que recorra el catalogo_productos e imprima el nombre y el precio de todos los productos que pertenezcan a la categoría "Electrónica".

# %% [markdown]
# ### 6. Calcular Valor Total del Inventario por Categoría
# - Calcula y imprime el valor total del inventario para la categoría "Alimentos". Esto se calcula como la suma de (precio * cantidad_en_stock) para todos los productos de esa ca- tegoría.

# %% [markdown]
# ### 7. Eliminar un Producto
# - El Teclado Mecánico RGB (ID 103) ha sido descontinuado. Elimínalo del catálogo. Des- pués de eliminarlo, intenta acceder a la información del producto con ID 103 (debería lanzar un error si lo haces directamente). Mejor, imprime el catálogo completo para confirmar su eli- minación.
