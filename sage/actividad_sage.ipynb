# %% [markdown]
# # Actividad: Resolución de problemas matemáticos usando Python (SageMath)
#
# ## 🎯 Objetivo:
#
# Aplicar el lenguaje **Python** con la librería **SageMath** para resolver ecuaciones algebraicas, sistemas de ecuaciones y simplificar expresiones simbólicas, utilizando herramientas computacionales para el razonamiento matemático.
#
# ## 📝 Instrucciones
#
#
# - A continuación se presentan **cuatro ejercicios** que debes resolver utilizando **únicamente código Python en la plataforma SageMath** de manera individual.
#
# - **Debajo de cada ejercicio**, escribe el código que utilizas para obtener la solución y verifica que funcione correctamente.
#
# - Puedes apoyarte en tus **apuntes de clases** y en los **códigos de actividades anteriores** desarrollados durante el curso.
#
# - Esta actividad tiene como objetivo **aplicar lo aprendido** sobre la resolución de problemas matemáticos mediante herramientas computacionales.
#
# ## ⚠️ Normas de uso
#
# - El uso de **software, páginas web o herramientas no autorizadas por el profesor** está **estrictamente prohibido**.
#
# - El **incumplimiento de esta norma** será **sancionado conforme a lo estipulado en el reglamento interno del colegio**.
#
# ## 💾 Entrega del archivo
# 1. Una vez finalizada la actividad, guarda tu archivo con el siguiente formato: `actividad_sage_nombre_apellido.ipynb`
#
#
# (Por ejemplo: **actividad_sage_maria_perez.ipynb**)
#
# 2. Para realizar la entrega:
#     - Ingresa a la página web del profesor: 👉 https://sites.google.com/view/profekenyer
#
#     - Busca el **formulario de entrega de actividad SageMath.**
#
#     - Completa tus datos y **sube el archivo** correspondiente para su revisión y corrección.
#     - En la página web podrás encontrar, además la rubrica de la evaluación sumativa 2.

# %% [markdown]
# ## ✏️ Ejercicio 1: Resolver ecuación en la variable U
#
# $$
# \left(\frac{u^2 - 12}{2}\right)^2 = u^2 + 12.
# $$

# %%
# Código solución problema 1

# %% [markdown]
# ## ✏️Ejercicio 2: Resolver el siguiente sistema de ecuaciones lineales en $m$ y $n$.
# $$
# \begin{cases}
# 3m - 4n &= 18 \\
# 5m + 2n &= 4
# \end{cases}
# $$

# %%
# Código solución problema 2

# %% [markdown]
# ## ✏️  Ejercicio 3:Resolver el siguiente sistema de ecuaciones en $p, q$.
# $$\begin{cases}
# 4p^2 + q^2 &= 68 \\
# pq &= 8
# \end{cases}
# $$

# %%
# código solución problema 3

# %% [markdown]
# ## ✏️ Ejercicio 4: Simplificar la siguiente expresión algebraica a su mínima expresión.
# $$\left(\frac{4^{n+1}\cdot 3^{n+1}+4^n \cdot 3^{2n}}{3\cdot 2^2+3^n}\right)^{\frac{1}{n}}$$

# %%
# código solución problema 4
